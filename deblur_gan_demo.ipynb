# %%
# !git clone https://github.com/mathurk29/deblur-gan.git
# Out:
# Cloning into 'deblur-gan'...
# remote: Counting objects: 66, done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 66 (delta 0), reused 0 (delta 0), pack-reused 63
# Unpacking objects: 100% (66/66), done.

# %%
# !pip install -r deblur-gan/requirements.txt
# !pip install -r deblur-gan/requirements-gpu.txt
# !pip install click
# Out:
# ...
#     100% |████████████████████████████████| 81kB 6.9MB/s
# ...
#     100% |████████████████████████████████| 71kB 19.8MB/s
# ...
#     100% |████████████████████████████████| 3.3MB 10.9MB/s
# ...
#     100% |████████████████████████████████| 327kB 22.0MB/s
# ...
#     100% |████████████████████████████████| 17.2MB 2.4MB/s
# ...
#     100% |████████████████████████████████| 5.9MB 7.3MB/s
# ...
#   Could not find a version that satisfies the requirement pkg-resources==0.0.0 (from -r deblur-gan/requirements.txt (line 17)) (from versions: )
# No matching distribution found for pkg-resources==0.0.0 (from -r deblur-gan/requirements.txt (line 17))
# ...
#   Using cached https://files.pythonhosted.org/packages/42/3c/1985d86a44bfe44fd060c02807336f840a509bfaa2d340860fba7d22da39/absl-py-0.1.9.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/34/c1/8806f99713ddb993c5366c362b2f908f18269f8d792aff1abfd700775a77/click-6.7-py2.py3-none-any.whl
# ...

# %%
import os
os.chdir("/content/deblur-gan")

# %%
# !python deblur_image.py --image_path a.png
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2018-06-12 17:12:03.610022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-06-12 17:12:03.610539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-06-12 17:12:03.610578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1435] Adding visible gpu devices: 0
# ...

# %%
from google.colab import files
files.download('deblura.png')
